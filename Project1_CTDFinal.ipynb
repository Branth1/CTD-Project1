# %% [markdown]
# <a href="https://colab.research.google.com/github/Branth1/CTD-Project1/blob/master/Project1_CTDFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Python Libraries

# %%
import pandas as pd
import datetime
from pandas import DataFrame
from datetime import timedelta
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Adjustment for Timestamp (Accounting for Difference of Epoch Time)

# %%
aa = datetime(1900, 1, 1)
bb = datetime(1970, 1, 1)
cc = timedelta(hours=8)
tdelta = bb-aa-cc

# %% [markdown]
# # Winter Data Analysis

# %% [markdown]
# ###Import Data Set for Winter:
# ### Coastal Endurance › Oregon Shelf Surface Piercing Profiler Mooring

# %%
url = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Dataset1.csv'
df1 = pd.read_csv(url)
df1
# Out:
#             obs          time  ...        lat         lon
# 0        ('0',)  3.750091e+09  ...  44.637117 -124.302617
# 1        ('1',)  3.750091e+09  ...  44.637117 -124.302617
# 2        ('2',)  3.750091e+09  ...  44.637117 -124.302617
# 3        ('3',)  3.750091e+09  ...  44.637117 -124.302617
# 4        ('4',)  3.750091e+09  ...  44.637117 -124.302617
# ...         ...           ...  ...        ...         ...
# 6127  ('6127',)  3.750177e+09  ...  44.637117 -124.302617
# 6128  ('6128',)  3.750177e+09  ...  44.637117 -124.302617
# 6129  ('6129',)  3.750177e+09  ...  44.637117 -124.302617
# 6130  ('6130',)  3.750177e+09  ...  44.637117 -124.302617
# 6131  ('6131',)  3.750177e+09  ...  44.637117 -124.302617
#
# [6132 rows x 27 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df1.temperature
y= df1.pressure
S= df1.salinity
z= df1.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.axvline(x=avg, color='r', linestyle='-')
plt.gca().invert_yaxis()
plt.legend (("Average(1491)","Data"))
plt.title('Coastal Endurance › Oregon Shelf Surface Piercing Profiler Mooring 11/01-11/02/18')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1491.03 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df1.time = pd.to_datetime(df1.time,unit='s')
time=df1.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ### Import Data Set for Winter:
# ### Coastal Endurance › Oregon Offshore Cabled Shallow Profiler Mooring

# %%
url2 = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data2.csv'
df2 = pd.read_csv(url2)
df2
# Out:
#               obs          time  ...       lat        lon
# 0          ('0',)  3.750667e+09  ...  44.37415 -124.95648
# 1          ('1',)  3.750667e+09  ...  44.37415 -124.95648
# 2          ('2',)  3.750667e+09  ...  44.37415 -124.95648
# 3          ('3',)  3.750667e+09  ...  44.37415 -124.95648
# 4          ('4',)  3.750667e+09  ...  44.37415 -124.95648
# ...           ...           ...  ...       ...        ...
# 27926  ('27926',)  3.750696e+09  ...  44.37415 -124.95648
# 27927  ('27927',)  3.750696e+09  ...  44.37415 -124.95648
# 27928  ('27928',)  3.750696e+09  ...  44.37415 -124.95648
# 27929  ('27929',)  3.750696e+09  ...  44.37415 -124.95648
# 27930  ('27930',)  3.750696e+09  ...  44.37415 -124.95648
#
# [27931 rows x 33 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df2.seawater_temperature
y= df2.seawater_pressure
S= df2.practical_salinity
z= df2.seawater_pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1485)","Data"))
plt.title('Coastal Endurance › Oregon Offshore Cabled Shallow Profiler Mooring 11/07-11/08/18')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1484.98 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df2.time = pd.to_datetime(df2.time,unit='s')
time=df2.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Winter:
# ## Coastal Endurance › Oregon Offshore Cabled Deep Profiler Mooring

# %%
url3 = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data3.csv'
df3 = pd.read_csv(url3)
df3
# Out:
#             obs          time  ...       lat       lon
# 0        ('0',)  3.655325e+09  ...  44.36829 -124.9528
# 1        ('1',)  3.655325e+09  ...  44.36829 -124.9528
# 2        ('2',)  3.655325e+09  ...  44.36829 -124.9528
# 3        ('3',)  3.655325e+09  ...  44.36829 -124.9528
# 4        ('4',)  3.655325e+09  ...  44.36829 -124.9528
# ...         ...           ...  ...       ...       ...
# 3804  ('3804',)  3.655411e+09  ...  44.36829 -124.9528
# 3805  ('3805',)  3.655411e+09  ...  44.36829 -124.9528
# 3806  ('3806',)  3.655411e+09  ...  44.36829 -124.9528
# 3807  ('3807',)  3.655411e+09  ...  44.36829 -124.9528
# 3808  ('3808',)  3.655411e+09  ...  44.36829 -124.9528
#
# [3809 rows x 30 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df3.temp
y= df3.pressure
S= df3.practical_salinity
z= df3.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1482)","Data"))
plt.title('Coastal Endurance › Oregon Offshore Cabled Shallow Profiler Mooring 11/01-11/02/15')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1481.94 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df3.time = pd.to_datetime(df3.time,unit='s')
time=df3.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Winter:
# ## Cabled Array  › Oregon Slope Base Shallow Profiler

# %%
url4 = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data4.csv'
df4 = pd.read_csv(url4)
df4
# Out:
#               obs  conductivity  ...  temperature          time
# 0          ('0',)       1490921  ...       408929  3.750667e+09
# 1          ('1',)       1490861  ...       408892  3.750667e+09
# 2          ('2',)       1490837  ...       408991  3.750667e+09
# 3          ('3',)       1490834  ...       409030  3.750667e+09
# 4          ('4',)       1490845  ...       409057  3.750667e+09
# ...           ...           ...  ...          ...           ...
# 23556  ('23556',)       1480073  ...       434598  3.750691e+09
# 23557  ('23557',)       1480073  ...       434598  3.750691e+09
# 23558  ('23558',)       1480071  ...       434599  3.750691e+09
# 23559  ('23559',)       1480070  ...       434599  3.750691e+09
# 23560  ('23560',)       1480069  ...       434598  3.750691e+09
#
# [23561 rows x 33 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df4.seawater_temperature
y= df4.seawater_pressure
S= df4.practical_salinity
z= df4.seawater_pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1485)","Data"))
plt.title('Cabled Array › Oregon Slope Base Shallow Profiler  11/07-11/08/18')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1484.52 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df4.port_timestamp = pd.to_datetime(df4.port_timestamp,unit='s')
time=df4.port_timestamp-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Winter:
# ## Cabled Array  › Oregon Slope Base DeepProfiler

# %%
url5 = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data5.csv'
df5 = pd.read_csv(url5)
df5
# Out:
#             obs  conductivity_millisiemens  ...  temp_qc_results          time
# 0        ('0',)                  31.469601  ...               29  3.655886e+09
# 1        ('1',)                  31.468000  ...               29  3.655886e+09
# 2        ('2',)                  31.466600  ...               29  3.655886e+09
# 3        ('3',)                  31.465200  ...               29  3.655886e+09
# 4        ('4',)                  31.465599  ...               29  3.655886e+09
# ...         ...                        ...  ...              ...           ...
# 1552  ('1552',)                  31.471100  ...               29  3.655904e+09
# 1553  ('1553',)                  31.471300  ...               29  3.655904e+09
# 1554  ('1554',)                  31.471100  ...               29  3.655904e+09
# 1555  ('1555',)                  31.471100  ...               29  3.655904e+09
# 1556  ('1556',)                  31.471100  ...               29  3.655904e+09
#
# ...

# %% [markdown]
# Define Variables for Plotting

# %%
x=df5.temp
y= df5.pressure
S= df5.practical_salinity
z= df5.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1489)","Data"))
plt.title('Cabled Array › Oregon Slope Base DeepProfiler   11/07-11/08/15')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1489.38 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df5.internal_timestamp = pd.to_datetime(df5.internal_timestamp,unit='s')
time=df5.internal_timestamp-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Winter:
# ## Cabled Array  › Axial Base ShallowProfiler

# %%
url6 = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data6.csv'
df6 = pd.read_csv(url6)
df6
# Out:
#               obs          time  ...       lat        lon
# 0          ('0',)  3.655454e+09  ...  45.83049 -129.75326
# 1          ('1',)  3.655454e+09  ...  45.83049 -129.75326
# 2          ('2',)  3.655454e+09  ...  45.83049 -129.75326
# 3          ('3',)  3.655454e+09  ...  45.83049 -129.75326
# 4          ('4',)  3.655454e+09  ...  45.83049 -129.75326
# ...           ...           ...  ...       ...        ...
# 28739  ('28739',)  3.655483e+09  ...  45.83049 -129.75326
# 28740  ('28740',)  3.655483e+09  ...  45.83049 -129.75326
# 28741  ('28741',)  3.655483e+09  ...  45.83049 -129.75326
# 28742  ('28742',)  3.655483e+09  ...  45.83049 -129.75326
# 28743  ('28743',)  3.655483e+09  ...  45.83049 -129.75326
#
# [28744 rows x 33 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df6.seawater_temperature
y= df6.seawater_pressure
S= df6.practical_salinity
z= df6.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1482)","Data"))
plt.title('Cabled Array › Axial Base ShallowProfiler   11/01-11/02/15')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  12820.27 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df6.time = pd.to_datetime(df6.time,unit='s')
time=df6.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Winter:
# ## Cabled Array  › Axial Base Deep Profiler

# %%
url7 = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data7.csv'
df7 = pd.read_csv(url7)
df7
# Out:
#               obs          time  ...       lat        lon
# 0          ('0',)  3.750624e+09  ...  45.82972 -129.75904
# 1          ('1',)  3.750624e+09  ...  45.82972 -129.75904
# 2          ('2',)  3.750624e+09  ...  45.82972 -129.75904
# 3          ('3',)  3.750624e+09  ...  45.82972 -129.75904
# 4          ('4',)  3.750624e+09  ...  45.82972 -129.75904
# ...           ...           ...  ...       ...        ...
# 34668  ('34668',)  3.750685e+09  ...  45.82972 -129.75904
# 34669  ('34669',)  3.750685e+09  ...  45.82972 -129.75904
# 34670  ('34670',)  3.750685e+09  ...  45.82972 -129.75904
# 34671  ('34671',)  3.750685e+09  ...  45.82972 -129.75904
# 34672  ('34672',)  3.750685e+09  ...  45.82972 -129.75904
#
# [34673 rows x 30 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df7.temp
y= df7.pressure
S= df7.practical_salinity
z= df7.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.avhline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1486)","Data"))
plt.title('Cabled Array › AAxial Base Deep Profiler   11/07-11/08/18')
print("The average is ", round(avg,2),"m/s")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-211-38cbcacf845a> in <module>()
#       5 plt.xlabel('SSP (m/s)')
#       6 plt.gca().invert_yaxis()
# ----> 7 plt.avhline(x=avg, color='r', linestyle='-')
#       8 plt.legend (("Average(1486)","Data"))
#       9 plt.title('Cabled Array › AAxial Base Deep Profiler   11/07-11/08/18')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'avhline'

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df7.time = pd.to_datetime(df7.time,unit='s')
time=df7.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# #Summer Data Analysis

# %% [markdown]
# ###Import Data Set for Summer:
# ### Coastal Endurance › Oregon Shelf Surface Piercing Profiler Mooring

# %%
urlS = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data1s.csv'
df1s = pd.read_csv(urlS)
df1s
# Out:
#               obs          time  ...      lat        lon
# 0          ('0',)  3.712680e+09  ...  44.6355 -124.30293
# 1          ('1',)  3.712680e+09  ...  44.6355 -124.30293
# 2          ('2',)  3.712680e+09  ...  44.6355 -124.30293
# 3          ('3',)  3.712680e+09  ...  44.6355 -124.30293
# 4          ('4',)  3.712680e+09  ...  44.6355 -124.30293
# ...           ...           ...  ...      ...        ...
# 16112  ('16112',)  3.712725e+09  ...  44.6355 -124.30293
# 16113  ('16113',)  3.712725e+09  ...  44.6355 -124.30293
# 16114  ('16114',)  3.712725e+09  ...  44.6355 -124.30293
# 16115  ('16115',)  3.712725e+09  ...  44.6355 -124.30293
# 16116  ('16116',)  3.712725e+09  ...  44.6355 -124.30293
#
# [16117 rows x 27 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df1s.temperature
y= df1s.pressure
S= df1s.salinity
z= df1s.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1485)","Data"))
plt.title('Coastal Endurance › Oregon Shelf Surface Piercing Profiler Mooring 8/25-8/26/117')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1484.65 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df1s.time = pd.to_datetime(df1s.time,unit='s')
time=df1s.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ### Import Data Set for Summer:
# ### Coastal Endurance › Oregon Offshore Cabled Shallow Profiler Mooring

# %%
url2s = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data2s.csv'
df2s = pd.read_csv(url2s)
df2s
# Out:
#               obs  conductivity  ...  temperature          time
# 0          ('0',)       1454057  ...       414765  3.681029e+09
# 1          ('1',)       1454018  ...       414776  3.681029e+09
# 2          ('2',)       1453958  ...       414781  3.681029e+09
# 3          ('3',)       1453895  ...       414789  3.681029e+09
# 4          ('4',)       1453872  ...       414797  3.681029e+09
# ...           ...           ...  ...          ...           ...
# 28477  ('28477',)       1430318  ...       451420  3.681057e+09
# 28478  ('28478',)       1430315  ...       451421  3.681057e+09
# 28479  ('28479',)       1430312  ...       451423  3.681057e+09
# 28480  ('28480',)       1430303  ...       451430  3.681057e+09
# 28481  ('28481',)       1430296  ...       451439  3.681057e+09
#
# [28482 rows x 33 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df2s.seawater_temperature
y= df2s.seawater_pressure
S= df2s.practical_salinity
z= df2s.seawater_pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1484)","Data"))
plt.title('Coastal Endurance › Oregon Offshore Cabled Shallow Profiler Mooring 8/23-8/24/16')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1484.07 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df2s.time = pd.to_datetime(df2s.time,unit='s')
time=df2s.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Summer:
# ## Coastal Endurance › Oregon Offshore Cabled Deep Profiler Mooring

# %%
url3s = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data3s.csv'
df3s = pd.read_csv(url3s)
df3s
# Out:
#               obs          time  ...       lat       lon
# 0          ('0',)  3.743793e+09  ...  44.36829 -124.9528
# 1          ('1',)  3.743793e+09  ...  44.36829 -124.9528
# 2          ('2',)  3.743793e+09  ...  44.36829 -124.9528
# 3          ('3',)  3.743793e+09  ...  44.36829 -124.9528
# 4          ('4',)  3.743793e+09  ...  44.36829 -124.9528
# ...           ...           ...  ...       ...       ...
# 11772  ('11772',)  3.743871e+09  ...  44.36829 -124.9528
# 11773  ('11773',)  3.743871e+09  ...  44.36829 -124.9528
# 11774  ('11774',)  3.743871e+09  ...  44.36829 -124.9528
# 11775  ('11775',)  3.743871e+09  ...  44.36829 -124.9528
# 11776  ('11776',)  3.743871e+09  ...  44.36829 -124.9528
#
# [11777 rows x 30 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df3s.temp
y= df3s.pressure
S= df3s.practical_salinity
z= df3s.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1480)","Data"))
plt.title('Coastal Endurance › Oregon Offshore Cabled Shallow Profiler Mooring 8/20-8/21/18')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1480.08 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df3s.time = pd.to_datetime(df3s.time,unit='s')
time=df3s.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Summer:
# ## Cabled Array  › Oregon Slope Base Shallow Profiler

# %%
url4s = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data4s.csv'
df4s = pd.read_csv(url4s)
df4s
# Out:
#               obs          time  ...       lat        lon
# 0          ('0',)  3.681029e+09  ...  44.52897 -125.38966
# 1          ('1',)  3.681029e+09  ...  44.52897 -125.38966
# 2          ('2',)  3.681029e+09  ...  44.52897 -125.38966
# 3          ('3',)  3.681029e+09  ...  44.52897 -125.38966
# 4          ('4',)  3.681029e+09  ...  44.52897 -125.38966
# ...           ...           ...  ...       ...        ...
# 24107  ('24107',)  3.681053e+09  ...  44.52897 -125.38966
# 24108  ('24108',)  3.681053e+09  ...  44.52897 -125.38966
# 24109  ('24109',)  3.681053e+09  ...  44.52897 -125.38966
# 24110  ('24110',)  3.681053e+09  ...  44.52897 -125.38966
# 24111  ('24111',)  3.681053e+09  ...  44.52897 -125.38966
#
# [24112 rows x 33 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df4s.seawater_temperature
y= df4s.seawater_pressure
S= df4s.practical_salinity
z= df4s.seawater_pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1486)","Data"))
plt.title('Cabled Array › Oregon Slope Base Shallow Profiler  8/23-8/24/16')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1486.09 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df4s.time = pd.to_datetime(df4s.time,unit='s')
time=df4s.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Summer:
# ## Cabled Array  › Oregon Slope Base DeepProfiler

# %%
url5s = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data5s.csv'
df5s = pd.read_csv(url5s)
df5s
# Out:
#               obs          time  ...       lat        lon
# 0          ('0',)  3.743776e+09  ...  44.52757 -125.38075
# 1          ('1',)  3.743776e+09  ...  44.52757 -125.38075
# 2          ('2',)  3.743776e+09  ...  44.52757 -125.38075
# 3          ('3',)  3.743776e+09  ...  44.52757 -125.38075
# 4          ('4',)  3.743776e+09  ...  44.52757 -125.38075
# ...           ...           ...  ...       ...        ...
# 39283  ('39283',)  3.743861e+09  ...  44.52757 -125.38075
# 39284  ('39284',)  3.743861e+09  ...  44.52757 -125.38075
# 39285  ('39285',)  3.743861e+09  ...  44.52757 -125.38075
# 39286  ('39286',)  3.743861e+09  ...  44.52757 -125.38075
# 39287  ('39287',)  3.743861e+09  ...  44.52757 -125.38075
#
# [39288 rows x 30 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df5s.temp
y= df5s.pressure
S= df5s.practical_salinity
z= df5s.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1489)","Data"))
plt.title('Cabled Array › Oregon Slope Base DeepProfiler   8/20-8/21/18')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1488.92 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df5s.time = pd.to_datetime(df5s.time,unit='s')
time=df5s.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Summer:
# ## Cabled Array  › Axial Base ShallowProfiler

# %%
url6s = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data6s.csv'
df6s = pd.read_csv(url6s)
df6s
# Out:
#               obs          time  ...       lat        lon
# 0          ('0',)  3.681029e+09  ...  45.83049 -129.75326
# 1          ('1',)  3.681029e+09  ...  45.83049 -129.75326
# 2          ('2',)  3.681029e+09  ...  45.83049 -129.75326
# 3          ('3',)  3.681029e+09  ...  45.83049 -129.75326
# 4          ('4',)  3.681029e+09  ...  45.83049 -129.75326
# ...           ...           ...  ...       ...        ...
# 36042  ('36042',)  3.681065e+09  ...  45.83049 -129.75326
# 36043  ('36043',)  3.681065e+09  ...  45.83049 -129.75326
# 36044  ('36044',)  3.681065e+09  ...  45.83049 -129.75326
# 36045  ('36045',)  3.681065e+09  ...  45.83049 -129.75326
# 36046  ('36046',)  3.681065e+09  ...  45.83049 -129.75326
#
# [36047 rows x 33 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df6s.seawater_temperature
y= df6s.seawater_pressure
S= df6s.practical_salinity
z= df6s.seawater_pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1488)","Data"))
plt.title('Cabled Array › Axial Base ShallowProfiler   8/23-8/24/16')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1488.45 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df6s.time = pd.to_datetime(df6s.time,unit='s')
time=df6s.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')

# %% [markdown]
# ## Import Data Set for Summer:
# ## Cabled Array  › Axial Base Deep Profiler

# %%
url7s = 'https://raw.githubusercontent.com/Branth1/CTD-Project1/master/Data7s.csv'
df7s = pd.read_csv(url7s)
df7s
# Out:
#               obs          time  ...       lat        lon
# 0          ('0',)  3.743799e+09  ...  45.82972 -129.75904
# 1          ('1',)  3.743799e+09  ...  45.82972 -129.75904
# 2          ('2',)  3.743799e+09  ...  45.82972 -129.75904
# 3          ('3',)  3.743799e+09  ...  45.82972 -129.75904
# 4          ('4',)  3.743799e+09  ...  45.82972 -129.75904
# ...           ...           ...  ...       ...        ...
# 32621  ('32621',)  3.743858e+09  ...  45.82972 -129.75904
# 32622  ('32622',)  3.743858e+09  ...  45.82972 -129.75904
# 32623  ('32623',)  3.743858e+09  ...  45.82972 -129.75904
# 32624  ('32624',)  3.743858e+09  ...  45.82972 -129.75904
# 32625  ('32625',)  3.743858e+09  ...  45.82972 -129.75904
#
# [32626 rows x 30 columns]

# %% [markdown]
# Define Variables for Plotting

# %%
x=df7s.temp
y= df7s.pressure
S= df7s.practical_salinity
z= df7s.pressure * 1.019977
x2=x*x
x3=x*x*x

# %% [markdown]
# Define SSP & Plot

# %%
c = 1449.2+(4.6*x) - (0.055*x2) + (0.00029*x3) + (1.34-0.01*x)*(S-35)+0.016*z
avg = sum(c)/len(c)
plt.scatter(c,z)
plt.ylabel('Depth (m)')
plt.xlabel('SSP (m/s)')
plt.gca().invert_yaxis()
plt.axvline(x=avg, color='r', linestyle='-')
plt.legend (("Average(1486)","Data"))
plt.title('Cabled Array › AAxial Base Deep Profiler   8/20-8/21/18')
print("The average is ", round(avg,2),"m/s")
# Out:
# The average is  1485.89 m/s

# %% [markdown]
# Plot Depth Vs Time to Determine # of Dives

# %%
df7s.time = pd.to_datetime(df7s.time,unit='s')
time=df7s.time-tdelta
plt.plot(time,z)
degrees = 50
plt.xticks(rotation=degrees)
plt.gca().invert_yaxis()
plt.xlabel('Time')
plt.ylabel('Depth (m)')
plt.title('Time Vs Depth (# of Dives)')
# Out:
# Text(0.5, 1.0, 'Time Vs Depth (# of Dives)')
